# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import scipy as sp

# %%
data = pd.read_csv('C:\data analytics\pandas_docs/ifood_df.csv')
data
# Out:
#        Income  Kidhome  Teenhome  Recency  MntWines  MntFruits  \
# 0     58138.0        0         0       58       635         88
# 1     46344.0        1         1       38        11          1
# 2     71613.0        0         0       26       426         49
# 3     26646.0        1         0       26        11          4
# 4     58293.0        1         0       94       173         43
# ...       ...      ...       ...      ...       ...        ...
# 2200  61223.0        0         1       46       709         43
# 2201  64014.0        2         1       56       406          0
# 2202  56981.0        0         0       91       908         48
# 2203  69245.0        0         1        8       428         30
# 2204  52869.0        1         1       40        84          3
#
#       MntMeatProducts  MntFishProducts  MntSweetProducts  MntGoldProds  ...  \
# 0                 546              172                88            88  ...
# ...

# %%
df = data.copy()

# %%
df.dtypes
# Out:
# Income                  float64
# Kidhome                   int64
# Teenhome                  int64
# Recency                   int64
# MntWines                  int64
# MntFruits                 int64
# MntMeatProducts           int64
# MntFishProducts           int64
# MntSweetProducts          int64
# MntGoldProds              int64
# NumDealsPurchases         int64
# NumWebPurchases           int64
# NumCatalogPurchases       int64
# NumStorePurchases         int64
# NumWebVisitsMonth         int64
# AcceptedCmp3              int64
# AcceptedCmp4              int64
# AcceptedCmp5              int64
# AcceptedCmp1              int64
# AcceptedCmp2              int64
# Complain                  int64
# Z_CostContact             int64
# Z_Revenue                 int64
# Response                  int64
# Age                       int64
# Customer_Days             int64
# marital_Divorced          int64
# marital_Married           int64
# marital_Single            int64
# ...

# %%
df.head()
# Out:
#     Income  Kidhome  Teenhome  Recency  MntWines  MntFruits  MntMeatProducts  \
# 0  58138.0        0         0       58       635         88              546
# 1  46344.0        1         1       38        11          1                6
# 2  71613.0        0         0       26       426         49              127
# 3  26646.0        1         0       26        11          4               20
# 4  58293.0        1         0       94       173         43              118
#
#    MntFishProducts  MntSweetProducts  MntGoldProds  ...  marital_Together  \
# 0              172                88            88  ...                 0
# 1                2                 1             6  ...                 0
# 2              111                21            42  ...                 1
# 3               10                 3             5  ...                 1
# 4               46                27            15  ...                 0
#
# ...

# %%
df.describe()
# Out:
#               Income      Kidhome     Teenhome      Recency     MntWines  \
# count    2205.000000  2205.000000  2205.000000  2205.000000  2205.000000
# mean    51622.094785     0.442177     0.506576    49.009070   306.164626
# std     20713.063826     0.537132     0.544380    28.932111   337.493839
# min      1730.000000     0.000000     0.000000     0.000000     0.000000
# 25%     35196.000000     0.000000     0.000000    24.000000    24.000000
# 50%     51287.000000     0.000000     0.000000    49.000000   178.000000
# 75%     68281.000000     1.000000     1.000000    74.000000   507.000000
# max    113734.000000     2.000000     2.000000    99.000000  1493.000000
#
#          MntFruits  MntMeatProducts  MntFishProducts  MntSweetProducts  \
# count  2205.000000      2205.000000      2205.000000       2205.000000
# mean     26.403175       165.312018        37.756463         27.128345
# std      39.784484       217.784507        54.824635         41.130468
# ...

# %%
df.columns
# Out:
# Index(['Income', 'Kidhome', 'Teenhome', 'Recency', 'MntWines', 'MntFruits',
#        'MntMeatProducts', 'MntFishProducts', 'MntSweetProducts',
#        'MntGoldProds', 'NumDealsPurchases', 'NumWebPurchases',
#        'NumCatalogPurchases', 'NumStorePurchases', 'NumWebVisitsMonth',
#        'AcceptedCmp3', 'AcceptedCmp4', 'AcceptedCmp5', 'AcceptedCmp1',
#        'AcceptedCmp2', 'Complain', 'Z_CostContact', 'Z_Revenue', 'Response',
#        'Age', 'Customer_Days', 'marital_Divorced', 'marital_Married',
#        'marital_Single', 'marital_Together', 'marital_Widow',
#        'education_2n Cycle', 'education_Basic', 'education_Graduation',
#        'education_Master', 'education_PhD', 'MntTotal', 'MntRegularProds',
#        'AcceptedCmpOverall'],
#       dtype='object')

# %% [markdown]
# - AcceptedCmp1 : customer accepted offer in the 1st campaign
# - AcceptedCmp2 : customer accepted offer in the 2nd campaign
# - AcceptedCmp3 : customer accepted offer in the 3rd campaign
# - AcceptedCmp4 : customer accepted offer in the 4th campaign
# - AcceptedCmp5 : customer accepted offer in the 5th campaign
# - Response(target) : customer accepted offer in the last campaign
# - Complain : customer complained in the last  2 yrs
#
# - Education : customer level of education
# - Martial : customers martial status
# - Income : customers yrly household income
# - Mnt : amount spent in last 2 yrs
# - NumDealsPurchases :no.of purchases made with discount
# - NumWebPurchases : no.of purchases made through company's web site
# - NumCatalogPurchases : no.of purchases made using catalog
# - NumStorePurchases : no.of purchases made directly in stores
# - NumWebVisitsMonth : no.of visits to company's web  site in the last month
# - Recency : no.of days since last purchase

# %%
df['NumDealsPurchases'].value_counts().plot(kind='bar',color='k')
# Out:
# <Axes: xlabel='NumDealsPurchases'>

# %% [markdown]
# - Number-1 company has the highest number of purchasing made with discount
# - Its more than 900

# %%
df['AcceptedCmp1'].value_counts().plot(kind='bar',color='blue')
# Out:
# <Axes: xlabel='AcceptedCmp1'>

# %% [markdown]
# - Most of the customers has rejected the offer in 1st campany

# %%
df['Response'].value_counts().plot(kind='bar',color='violet')
# Out:
# <Axes: xlabel='Response'>

# %% [markdown]
# - Most of the customers rejected the offer in the last company

# %%
df['Complain'].value_counts().plot(kind='bar',color='k')
# Out:
# <Axes: xlabel='Complain'>

# %% [markdown]
# - Only few customers have the complaineds

# %%
df['education_Graduation'].value_counts().plot(kind='bar',color='brown',grid=True)
# Out:
# <Axes: xlabel='education_Graduation'>

# %%
df['education_Graduation'].value_counts()
# Out:
# education_Graduation
# 1    1113
# 0    1092
# Name: count, dtype: int64

# %% [markdown]
# - Number of gratuated customers is highrer

# %%
sns.catplot(data=df,x='education_Master',y='Income',kind='swarm',color='k')
plt.show()
# Out:
# C:\Users\hp\anaconda3\Lib\site-packages\seaborn\categorical.py:3544: UserWarning: 14.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\hp\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# C:\Users\hp\anaconda3\Lib\site-packages\seaborn\categorical.py:3544: UserWarning: 51.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# - In this fig most of the customers has no master degree
# - And the highest yearly household income is a customer who have no master degree

# %%
sns.catplot(data=df,y='MntTotal',x='AcceptedCmp3',kind='bar')
# Out:
# C:\Users\hp\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# - Highest amount spent in last 2 years is a customer who accepted the offer from the 3rd company

# %%
df['Income']
# Out:
# 0       58138.0
# 1       46344.0
# 2       71613.0
# 3       26646.0
# 4       58293.0
#          ...
# 2200    61223.0
# 2201    64014.0
# 2202    56981.0
# 2203    69245.0
# 2204    52869.0
# Name: Income, Length: 2205, dtype: float64

# %%
income = pd.crosstab(index=df['Income'],columns='count')
income.reset_index(inplace=True)
income
# Out:
# col_0    Income  count
# 0        1730.0      1
# 1        2447.0      1
# 2        3502.0      1
# 3        4023.0      1
# 4        4428.0      1
# ...         ...    ...
# 1958   101970.0      1
# 1959   102160.0      1
# 1960   102692.0      1
# 1961   105471.0      1
# 1962   113734.0      1
#
# [1963 rows x 2 columns]

# %%
income[income['count']==df['Income'].value_counts().max()]
# Out:
# col_0  Income  count
# 11     7500.0     12

# %% [markdown]
# - This is the yearly household income of most of the customers

# %%
IQR = df['Income'].quantile(0.75) - df['Income'].quantile(0.25)
IQR
# Out:
# 33085.0

# %% [markdown]
# - This is the IQR of customers yealy household income

# %%
std_data = pd.DataFrame(df.loc[:,[]])
